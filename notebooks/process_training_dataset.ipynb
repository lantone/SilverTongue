# %%
import srt
import json
import datetime
import string
import speechace
import textprocessing
import re
from pydub import AudioSegment
import matplotlib.pyplot as plt
import numpy as np
import jupyternotify
import re
import codecs
import glob
ip = get_ipython()
ip.register_magics(jupyternotify.JupyterNotifyMagics)

# %%
def vtt_to_srt(input, output):
    outlines= []
    with codecs.open(input,'r', 'utf-8') as f:
        lines = f.readlines()
    index = 0
    for line in lines[:-1]:
        if line == "WEBVTT\n":
            continue
        if line.startswith('Kind:'):
            continue
        if line.startswith('Language:'):
            continue
        if 'Translator:' in line:
            continue
        if 'Reviewer:' in line:
            continue
        altered_line = re.sub(r'([\d]+)\.([\d]+)', r'\1,\2', line)
        outlines.append(altered_line)
        if line == "\n":
            outlines.append(str(index)+'\n')
            index += 1
                        
    outfile = codecs.open(output, "w", "utf-8")
    for line in outlines[1:]:
        outfile.write(line)
    outfile.close()

# %%
def fix_srt_overlap(subtitles):
    # FIX OVERLAPPING SUBTITLES!!
    if subtitles[0].end > subtitles[1].start:
        for i in range(len(subtitles)-1):
            subtitles[i].end = subtitles[i+1].start
    return subtitles

def split_subtitles(subtitles, target_length = 30):
    # split files into chunks for use with speechace API
    indices_to_split = []
    running_length = 0
    for i,subtitle in enumerate(subtitles):
        sub_length = subtitle.end - subtitle.start
        running_length += sub_length.total_seconds()
        if running_length >= target_length:
            indices_to_split.append(i)
            running_length = 0
    # add final index 
    indices_to_split.append(len(subtitles))
    return indices_to_split

def prepare_subtitle_chunks(subtitles, indices_to_split):
    # split text into chunks

    start_chunk = 0
    subs_for_speechace = []
    for i in indices_to_split:
        # get text and remove newline characters
        text = ' '.join(str(i.content.encode('utf-8').replace('\n',' ')) for i in subtitles[start_chunk:i])
        # remove HTML color codes
        text = re.sub('<[^<]+?>', '', text)
        # turn numbers into text
        text = textprocessing.replace_numbers(text)
        # remove punctuation
        text = ' '.join(word.strip(string.punctuation) for word in text.split())
        start_chunk = i
        subs_for_speechace.append(text)
    return subs_for_speechace

def prepare_audio_chunks(audio, indices_to_split):
    # split audio into chunks
    start_chunk = 0
    audio_for_speechace = []
    index = 0
    for i in indices_to_split:
        #print start_chunk,'-',i-1
        start = 1000*subtitles[start_chunk].start.total_seconds()
        end = 1000*subtitles[i-1].end.total_seconds()
        audio_chunk = audio[start:end]
        #print start, end
        audio_chunk.export(data_dir+"audio_chunk{0}.wav".format(index), format="wav")
        audio_for_speechace.append(data_dir+"audio_chunk{0}.wav".format(index))

        index += 1
        start_chunk = i
    return audio_for_speechace


def activate_speechace(subs_for_speechace, audio_for_speechace, max_calls = 999):
    # API calls!!!
    data_for_speechace = zip(audio_for_speechace, subs_for_speechace)
    word_list = []
    bad_chunks = []
    unknown_word_list = []
    print len(data_for_speechace)
    start_time = datetime.datetime.now()
    last_time = start_time
    total_time = 0
    for i,chunk in enumerate(data_for_speechace):
        print "call #" + str(i)
        if i >= max_calls:
            break
        speechace_data = speechace.query(chunk[0],chunk[1])
        if 'status' not in speechace_data:
            print speechace_data
            print "NO GO #1"
            bad_chunks.append(i)
            continue
        if speechace_data['status'] == 'success':
            word_list.extend(speechace.create_word_list(speechace_data))
        else:
            if speechace_data['short_message'] == 'error_unknown_words':
                print "found unknown_words!"
                unknown_words = speechace_data['detail_message'].encode('utf-8').split(':')[-1].split(',')
                new_text = chunk[1]
                for unknown_word in unknown_words:
                    unknown_word_list.append(unknown_word.strip())
                    new_text = new_text.replace(unknown_word,'')
                speechace_data = speechace.query(chunk[0],new_text)
                if 'status' not in speechace_data:
                    print "NO GO"
                    bad_chunks.append(i)
                    continue
                if speechace_data['status'] == 'success':
                    word_list.extend(speechace.create_word_list(speechace_data))
                else:
                    print speechace_data['short_message']
                    print "NO GO"
                    bad_chunks.append(i)
            else:
                print speechace_data['short_message']
                print "NO GO"
                bad_chunks.append(i)

        current_time = datetime.datetime.now()        
        print "took", (current_time-last_time).total_seconds()
        print "total time is", (current_time-start_time).total_seconds()
        print
        last_time = current_time
    return word_list, bad_chunks, unknown_word_list

# %%
data_dir = '/Users/lantonel/SilverTongue/data/'
input_dir = '/Users/lantonel/SilverTongue/training_dataset/'

all_inputs = [name.split('/')[-1].split('.')[0] for name in glob.glob(input_dir+"*vtt")]
print len(all_inputs), "total talks"

#done_list = ['N4wFyRGilp4', 'NA7krbsdXFA']
done_list = [name.split('/')[-1].split('.')[0] for name in glob.glob(input_dir+"*.json")]
#print len(done_list),"already processed"

inputs = [input for input in all_inputs if input not in done_list]

#inputs = ['NqOjj1FCcVY']
print len(inputs),"to process"

print len(all_inputs) - len(inputs), "already processed!!"
#print all_inputs
#print done_list
#print inputs
# Out:
# 355 total talks
# 0 to process
# 355 already processed!!

# %%
# %%notify
# for input_name in inputs:
#     print "processing input with ID", input_name
#     audio_file = input_dir + input_name + ".m4a"
#     vtt_file = input_dir + input_name + ".en.vtt"
#     srt_file = input_dir + input_name + ".en.srt"
#
#     # fix subtitle file and convert to srt
#     vtt_to_srt(vtt_file, srt_file)
#
#     # process subtitle file and split into chunks
#     with codecs.open(srt_file,'r', 'utf-8') as myfile:
#         data = myfile.read()
#     subtitle_generator = srt.parse(data)
#     subtitles = list(subtitle_generator)
#     subtitles = fix_srt_overlap(subtitles)
#     indices_to_split = split_subtitles(subtitles)
#     subs_for_speechace = prepare_subtitle_chunks(subtitles, indices_to_split)
#
#
#     # process audio file and split into chunks
#     audio = AudioSegment.from_file(audio_file).split_to_mono()[0].set_frame_rate(16000)
#     print "file is ",len(audio)/1000.,"seconds long (",len(audio)/60000.,") minutes"
#     audio_for_speechace = prepare_audio_chunks(audio, indices_to_split)
#
#     word_list, bad_chunks, unknown_word_list = activate_speechace(subs_for_speechace,
#                                                                   audio_for_speechace,
#                                                                   max_calls = 999)
#     print "unknown_word_list:",unknown_word_list
#     with open(input_dir+input_name+'.json', mode='w') as outputFile:
#         json.dump(word_list, outputFile, indent=4)
#     with open(input_dir+input_name+'_unknown_words.json', mode='w') as outputFile:
#         json.dump(unknown_word_list, outputFile, indent=4)
#     word_scores = [word["quality"] for word in word_list]
#
#
#     plot = plt.hist(word_scores,
#                     100,
#                     range=[0, 100],
#                     histtype='step'
#                    )
#
#     axes = plt.gca()
#     axes.set_xlabel("Word Score")
#     axes.set_ylabel("A.U. (unit norm)")
#     axes.set_xlim(0,100)
#     plt.savefig('word_scores_'+input_name+'.pdf', transparent=True,bbox_inches='tight')
#     plt.clf()
#     indices = [i for i in range(len(word_list))]
#
#     plot = plt.scatter(indices,word_scores)
#     plt.savefig('word_scores_vs_index_'+input_name+'.pdf', transparent=True,bbox_inches='tight')
#     plt.clf()
# Out:
# processing input with ID o8NPllzkFhE
# file is  1290.027 seconds long ( 21.50045 ) minutes
# 39
# call #0
# took 13.894299
# total time is 13.894299
#
# call #1
# found unknown_words!
# took 21.182864
# total time is 35.077163
#
# call #2
# took 14.43843
# total time is 49.515593
#
# call #3
# took 11.097227
# total time is 60.61282
#
# call #4
# found unknown_words!
# took 13.943384
# total time is 74.556204
#
# call #5
# took 11.795466
# total time is 86.35167
#
# call #6
# took 13.094896
# total time is 99.446566
#
# call #7
# took 12.641454
# total time is 112.08802
#
# call #8
# found unknown_words!
# took 16.521135
# total time is 128.609155
#
# call #9
# took 12.93163
# total time is 141.540785
#
# call #10
# took 13.13819
# total time is 154.678975
#
# call #11
# found unknown_words!
# took 15.322184
# total time is 170.001159
#
# call #12
# took 12.2672
# total time is 182.268359
#
# call #13
# found unknown_words!
# took 15.189717
# total time is 197.458076
#
# call #14
# found unknown_words!
# took 15.054787
# total time is 212.512863
#
# call #15
# found unknown_words!
# error_unknown_words
# NO GO
# took 3.065789
# total time is 215.578652
#
# call #16
# found unknown_words!
# took 14.833991
# total time is 230.412643
#
# call #17
# found unknown_words!
# took 15.140304
# total time is 245.552947
#
# call #18
# took 13.570811
# total time is 259.123758
#
# call #19
# found unknown_words!
# took 15.400999
# total time is 274.524757
#
# call #20
# found unknown_words!
# took 14.523883
# total time is 289.04864
#
# call #21
# took 13.745608
# total time is 302.794248
#
# call #22
# took 12.63379
# total time is 315.428038
#
# call #23
# took 12.414838
# total time is 327.842876
#
# call #24
# found unknown_words!
# took 14.756165
# total time is 342.599041
#
# call #25
# found unknown_words!
# took 16.140534
# total time is 358.739575
#
# call #26
# found unknown_words!
# took 13.850697
# total time is 372.590272
#
# call #27
# found unknown_words!
# took 15.29467
# total time is 387.884942
#
# call #28
# took 12.526014
# total time is 400.410956
#
# call #29
# found unknown_words!
# took 15.726773
# total time is 416.137729
#
# call #30
# took 14.487368
# total time is 430.625097
#
# call #31
# found unknown_words!
# error_unknown_words
# NO GO
# took 3.272125
# total time is 433.897222
#
# call #32
# took 12.520161
# total time is 446.417383
#
# call #33
# found unknown_words!
# took 14.326163
# total time is 460.743546
#
# call #34
# {}
# NO GO #1
# call #35
# {}
# NO GO #1
# call #36
# took 14.853741
# total time is 475.597287
#
# call #37
# found unknown_words!
# NO GO
# call #38
# {}
# NO GO #1
# unknown_word_list: ['Torvalds', 'LT', 'LT', 'LT', 'LT', 'CVS', 'CVS', 'LT', 'LT', 'LT', '\xc3\xbcbernerd', 'LT', 'LT', 'LT', 'UI', 'UI', 'UI', 'LT', 'LT', 'LT', 'LT', 'LT', 'LT', 'clich\xc3\xa9', 'LT', 'LT', 'arXiv', 'Wikipedia', 'LT', 'Torvalds', 'LT']
# processing input with ID OIpgrZ8yS-Q
# file is  537.024 seconds long ( 8.9504 ) minutes
# 16
# call #0
# took 12.726188
# total time is 12.726188
#
# call #1
# {}
# NO GO #1
# call #2
# {}
# NO GO #1
# call #3
# took 13.930577
# total time is 26.656765
#
# call #4
# took 13.695453
# total time is 40.352218
#
# call #5
# took 13.647014
# total time is 53.999232
#
# call #6
# found unknown_words!
# took 15.703356
# total time is 69.702588
#
# call #7
# found unknown_words!
# took 18.297062
# total time is 87.99965
#
# call #8
# took 15.741517
# total time is 103.741167
#
# call #9
# took 13.640992
# total time is 117.382159
#
# call #10
# took 13.985322
# total time is 131.367481
#
# call #11
# took 12.977491
# total time is 144.344972
#
# call #12
# found unknown_words!
# took 15.117975
# total time is 159.462947
#
# call #13
# took 13.972279
# total time is 173.435226
#
# call #14
# took 13.808821
# total time is 187.244047
#
# call #15
# took 16.228674
# total time is 203.472721
#
# unknown_word_list: ['Facebook', 'Renuncia', 'huevos', 'homeschool']
# processing input with ID P9B8PmUR64U
# file is  440.832 seconds long ( 7.3472 ) minutes
# 13
# call #0
# found unknown_words!
# took 14.021708
# total time is 14.021708
#
# call #1
# took 13.475361
# total time is 27.497069
#
# call #2
# took 12.929266
# total time is 40.426335
#
# call #3
# took 13.225336
# total time is 53.651671
#
# call #4
# took 13.301314
# total time is 66.952985
#
# call #5
# took 13.42437
# total time is 80.377355
#
# call #6
# took 13.314947
# total time is 93.692302
#
# call #7
# found unknown_words!
# took 15.020012
# total time is 108.712314
#
# call #8
# took 14.253086
# total time is 122.9654
#
# call #9
# took 11.707444
# total time is 134.672844
#
# call #10
# took 13.987566
# total time is 148.66041
#
# call #11
# took 13.357028
# total time is 162.017438
#
# call #12
# took 6.951021
# total time is 168.968459
#
# unknown_word_list: ['Highbury', 'whiteboard', 'UNIH']
# processing input with ID Qs9m8obl0AY
# file is  588.395 seconds long ( 9.80658333333 ) minutes
# 16
# call #0
# took 12.030491
# total time is 12.030491
#
# call #1
# found unknown_words!
# took 18.048234
# total time is 30.078725
#
# call #2
# found unknown_words!
# took 16.473941
# total time is 46.552666
#
# call #3
# took 14.324035
# total time is 60.876701
#
# call #4
# took 14.858131
# total time is 75.734832
#
# call #5
# took 13.361619
# total time is 89.096451
#
# call #6
# found unknown_words!
# took 16.227718
# total time is 105.324169
#
# call #7
# found unknown_words!
# took 15.660178
# total time is 120.984347
#
# call #8
# took 13.744757
# total time is 134.729104
#
# call #9
# found unknown_words!
# took 19.226541
# total time is 153.955645
#
# call #10
# found unknown_words!
# took 14.954682
# total time is 168.910327
#
# call #11
# found unknown_words!
# took 15.809775
# total time is 184.720102
#
# call #12
# took 13.059985
# total time is 197.780087
#
# call #13
# took 11.049209
# total time is 208.829296
#
# call #14
# found unknown_words!
# took 23.723547
# total time is 232.552843
#
# call #15
# took 5.768797
# total time is 238.32164
#
# unknown_word_list: ['BFIB', 'BFIB', 'BFIB', 'TBI', 'neuroimaging', "Broca's", 'NICoE', 'TBI', 'accesses', 'nonthreatening', 'reintegrating', 'hemispheres', 'BFIB', 'BFIB', 'BFIB', 'NICoE', 'BFIB', 'BFIB', 'BFIB', 'TBI']
# processing input with ID rToBZSrxjgM
# file is  589.077 seconds long ( 9.81795 ) minutes
# 18
# call #0
# found unknown_words!
# took 14.228846
# total time is 14.228846
#
# call #1
# found unknown_words!
# took 14.179987
# total time is 28.408833
#
# call #2
# found unknown_words!
# took 14.603137
# total time is 43.01197
#
# call #3
# found unknown_words!
# took 19.194925
# total time is 62.206895
#
# call #4
# found unknown_words!
# took 16.525594
# total time is 78.732489
#
# call #5
# found unknown_words!
# took 14.577711
# total time is 93.3102
#
# call #6
# took 12.779294
# total time is 106.089494
#
# call #7
# found unknown_words!
# took 13.621574
# total time is 119.711068
#
# call #8
# found unknown_words!
# took 13.944165
# total time is 133.655233
#
# call #9
# found unknown_words!
# took 15.362066
# total time is 149.017299
#
# call #10
# took 12.03959
# total time is 161.056889
#
# call #11
# took 12.500878
# total time is 173.557767
#
# call #12
# took 12.715886
# total time is 186.273653
#
# call #13
# took 14.109285
# total time is 200.382938
#
# call #14
# took 13.213024
# total time is 213.595962
#
# call #15
# took 12.705167
# total time is 226.301129
#
# call #16
# found unknown_words!
# took 14.560636
# total time is 240.861765
#
# call #17
# took 4.943505
# total time is 245.80527
#
# unknown_word_list: ['copyediting', 'na\xc3\xafve', 'co\xc3\xb6perate', 'Copyediting', 'copyediting', 'cop/bad', 'no-nothingism', 'know-nothingism', 'no-nothingism', 'E.B', 'cri', 'Fie', 'oversights', 'miked']
# processing input with ID Sd7lvPpDDUg
# file is  289.365 seconds long ( 4.82275 ) minutes
# 9
# call #0
# found unknown_words!
# took 12.931836
# total time is 12.931836
#
# call #1
# found unknown_words!
# error_unknown_words
# NO GO
# took 3.307398
# total time is 16.239234
#
# call #2
# found unknown_words!
# error_unknown_words
# NO GO
# took 3.450324
# total time is 19.689558
#
# call #3
# took 12.494413
# total time is 32.183971
#
# call #4
# found unknown_words!
# took 13.940115
# total time is 46.124086
#
# call #5
# found unknown_words!
# took 15.154705
# total time is 61.278791
#
# call #6
# found unknown_words!
# took 14.19167
# total time is 75.470461
#
# call #7
# found unknown_words!
# took 14.704543
# total time is 90.175004
#
# call #8
# took 7.018008
# total time is 97.193012
#
# unknown_word_list: ['YOLO', 'YOLO', 'cavefish', 'cavefishes', 'cavefish', 'cavefish', 'Amblyopsis', 'hoosieri', 'cavefish', 'cavefishes', 'cavefishes', 'Typhleotris', 'mararybe', 'sinkholes', 'YOLO', 'cavefishes', 'cavefish', 'cavefishes', 'cavefishes']
# processing input with ID tRqJysI-yiw
# file is  363.392 seconds long ( 6.05653333333 ) minutes
# 11
# call #0
# took 11.700372
# total time is 11.700372
#
# call #1
# took 14.418595
# total time is 26.118967
#
# call #2
# took 13.463579
# total time is 39.582546
#
# call #3
# took 14.977582
# total time is 54.560128
#
# call #4
# took 12.710638
# total time is 67.270766
#
# call #5
# took 14.399137
# total time is 81.669903
#
# call #6
# took 14.202445
# total time is 95.872348
#
# call #7
# took 14.165459
# total time is 110.037807
#
# call #8
# took 14.203114
# total time is 124.240921
#
# call #9
# took 14.641836
# total time is 138.882757
#
# call #10
# took 6.811929
# total time is 145.694686
#
# unknown_word_list: []
# processing input with ID TvcNw4F0Y4Y
# file is  449.771 seconds long ( 7.49618333333 ) minutes
# 13
# call #0
# took 12.099443
# total time is 12.099443
#
# call #1
# took 13.107484
# total time is 25.206927
#
# call #2
# took 13.55629
# total time is 38.763217
#
# call #3
# took 14.29309
# total time is 53.056307
#
# call #4
# took 12.525386
# total time is 65.581693
#
# call #5
# took 13.482778
# total time is 79.064471
#
# call #6
# took 13.637647
# total time is 92.702118
#
# call #7
# took 13.249725
# total time is 105.951843
#
# call #8
# took 12.649332
# total time is 118.601175
#
# call #9
# took 13.529238
# total time is 132.130413
#
# call #10
# found unknown_words!
# took 15.111164
# total time is 147.241577
#
# call #11
# took 12.151052
# total time is 159.392629
#
# call #12
# took 14.744724
# total time is 174.137353
#
# unknown_word_list: ['SumAll']
# processing input with ID U7y4GlmwPLQ
# file is  1234.603 seconds long ( 20.5767166667 ) minutes
# 35
# call #0
# found unknown_words!
# took 14.873453
# total time is 14.873453
#
# call #1
# took 13.531528
# total time is 28.404981
#
# call #2
# took 15.392404
# total time is 43.797385
#
# call #3
# found unknown_words!
# took 14.053108
# total time is 57.850493
#
# call #4
# took 12.588029
# total time is 70.438522
#
# call #5
# took 13.72824
# total time is 84.166762
#
# call #6
# took 13.093766
# total time is 97.260528
#
# call #7
# took 13.927532
# total time is 111.18806
#
# call #8
# found unknown_words!
# took 15.82987
# total time is 127.01793
#
# call #9
# found unknown_words!
# took 15.695731
# total time is 142.713661
#
# call #10
# found unknown_words!
# took 16.333468
# total time is 159.047129
#
# call #11
# found unknown_words!
# took 13.933338
# total time is 172.980467
#
# call #12
# found unknown_words!
# took 17.934125
# total time is 190.914592
#
# call #13
# took 12.739462
# total time is 203.654054
#
# call #14
# found unknown_words!
# took 15.070643
# total time is 218.724697
#
# call #15
# found unknown_words!
# took 15.737083
# total time is 234.46178
#
# call #16
# found unknown_words!
# took 14.789892
# total time is 249.251672
#
# call #17
# took 12.261796
# total time is 261.513468
#
# call #18
# took 13.625332
# total time is 275.1388
#
# call #19
# found unknown_words!
# took 14.830679
# total time is 289.969479
#
# call #20
# took 12.670323
# total time is 302.639802
#
# call #21
# took 15.883868
# total time is 318.52367
#
# call #22
# took 13.59508
# total time is 332.11875
#
# call #23
# took 14.560316
# total time is 346.679066
#
# call #24
# found unknown_words!
# took 14.437524
# total time is 361.11659
#
# call #25
# found unknown_words!
# took 15.737688
# total time is 376.854278
#
# call #26
# took 12.907332
# total time is 389.76161
#
# call #27
# took 13.009905
# total time is 402.771515
#
# call #28
# took 12.568034
# total time is 415.339549
#
# call #29
# took 14.169564
# total time is 429.509113
#
# call #30
# took 13.203353
# total time is 442.712466
#
# call #31
# took 13.739826
# total time is 456.452292
#
# call #32
# took 13.025395
# total time is 469.477687
#
# call #33
# took 12.755112
# total time is 482.232799
#
# call #34
# took 15.812238
# total time is 498.045037
#
# unknown_word_list: ['reimagine', 'connectography', 'Connectography', 'megatrend', 'archipelagos', 'Cascadia', 'megacities', 'megacity', 'megacity', 'Bohai', 'megacity', 'megacity', 'megacities', 'megacity', 'megacity', 'megacity', 'megacity', 'megacity', 'Gauteng', 'megacities', 'postcolonial', 'Asiana', 'multimodal', 'Africana']
# processing input with ID VSUWNy_-pLI
# file is  237.205 seconds long ( 3.95341666667 ) minutes
# 8
# call #0
# took 11.629344
# total time is 11.629344
#
# call #1
# found unknown_words!
# took 14.230495
# total time is 25.859839
#
# call #2
# took 12.135733
# total time is 37.995572
#
# call #3
# took 12.780007
# total time is 50.775579
#
# call #4
# took 12.239266
# total time is 63.014845
#
# call #5
# took 13.083116
# total time is 76.097961
#
# call #6
# took 10.15652
# total time is 86.254481
#
# call #7
# took 4.170716
# total time is 90.425197
#
# unknown_word_list: ['caterwauled']
# processing input with ID xgYtUKFzHf8
# file is  518.943 seconds long ( 8.64905 ) minutes
# 15
# call #0
# took 20.641763
# total time is 20.641763
#
# call #1
# took 12.209034
# total time is 32.850797
#
# call #2
# took 14.051227
# total time is 46.902024
#
# call #3
# took 14.835595
# total time is 61.737619
#
# call #4
# took 14.843767
# total time is 76.581386
#
# call #5
# took 12.843269
# total time is 89.424655
#
# call #6
# took 12.971016
# total time is 102.395671
#
# call #7
# took 15.921702
# total time is 118.317373
#
# call #8
# took 12.429937
# total time is 130.74731
#
# call #9
# found unknown_words!
# took 23.251422
# total time is 153.998732
#
# call #10
# took 13.157585
# total time is 167.156317
#
# call #11
# found unknown_words!
# took 15.061584
# total time is 182.217901
#
# call #12
# took 12.214609
# total time is 194.43251
#
# call #13
# found unknown_words!
# took 13.07913
# total time is 207.51164
#
# call #14
# took 3.697236
# total time is 211.208876
#
# unknown_word_list: ['parkour', 'Hala', 'fixers']
# processing input with ID XiDAztWWAuM
# file is  485.645 seconds long ( 8.09408333333 ) minutes
# 15
# call #0
# took 12.312747
# total time is 12.312747
#
# call #1
# took 13.280853
# total time is 25.5936
#
# call #2
# found unknown_words!
# took 13.522811
# total time is 39.116411
#
# call #3
# found unknown_words!
# took 13.479493
# total time is 52.595904
#
# call #4
# found unknown_words!
# took 16.075582
# total time is 68.671486
#
# call #5
# took 13.147513
# total time is 81.818999
#
# call #6
# found unknown_words!
# took 14.558261
# total time is 96.37726
#
# call #7
# found unknown_words!
# took 15.07806
# total time is 111.45532
#
# call #8
# found unknown_words!
# took 14.085585
# total time is 125.540905
#
# call #9
# found unknown_words!
# took 17.499426
# total time is 143.040331
#
# call #10
# found unknown_words!
# took 15.39991
# total time is 158.440241
#
# call #11
# took 13.182576
# total time is 171.622817
#
# call #12
# took 13.606048
# total time is 185.228865
#
# call #13
# found unknown_words!
# took 15.758106
# total time is 200.986971
#
# call #14
# took 11.057402
# total time is 212.044373
#
# unknown_word_list: ['trolls', 'YouTube', 'old-timey', 'sluts', 'Muzzies', 'MTA', 'Obeidallah', 'MTA', 'MTA', 'frittatas', 'MTA', 'fighting-bigortry', 'thedailydenouncer.com', 'tweets']
# processing input with ID Znc6TJAAXFU
# file is  518.85 seconds long ( 8.6475 ) minutes
# 13
# call #0
# took 11.736841
# total time is 11.736841
#
# call #1
# took 13.388589
# total time is 25.12543
#
# call #2
# took 12.143369
# total time is 37.268799
#
# call #3
# took 15.366234
# total time is 52.635033
#
# call #4
# took 14.832614
# total time is 67.467647
#
# call #5
# found unknown_words!
# took 15.801832
# total time is 83.269479
#
# call #6
# found unknown_words!
# took 16.971113
# total time is 100.240592
#
# call #7
# {}
# NO GO #1
# call #8
# took 89.261062
# total time is 189.501654
#
# call #9
# took 39.574103
# total time is 229.075757
#
# call #10
# took 19.660013
# total time is 248.73577
#
# call #11
# took 38.516622
# total time is 287.252392
#
# call #12
# took 15.541074
# total time is 302.793466
#
# unknown_word_list: ['singin', 'gon', 'screamin']
